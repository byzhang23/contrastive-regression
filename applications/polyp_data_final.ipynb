# %%
import sys
sys.path.append("contrastive-regression/models/")
from linear_cr_bz import LinearCRBZ
import scanpy as sc

# %%
import pandas as pd

# %%
data = pd.read_csv("data/polyps/SuppTable2_PolypALL_merged.txt.gz",sep="\t",index_col=0)

# %%
data = data.T

# %%
meta = pd.read_csv("data/polyps/np_alexandria_meta_with_sss.csv",index_col=0 )
# Out:
# /scratch/snyquist/ipykernel_3148906/3066979459.py:1: DtypeWarning: Columns (6,10,11,16,17,33,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv("data/polyps/np_alexandria_meta_with_sss.csv",index_col=0 )

# %%
no_polyp_order = pd.read_csv("data/polyps/no_polyp_epithelial_pseudotime_order.csv",header=None, index_col=0)

# %%
no_polyp_cells = data.loc[no_polyp_order.index]

# %%
polyp_order = pd.read_csv("data/polyps/polyp_epithelial_pseudotime_order.csv",header=None, index_col=0)

# %%
polyp_cells = data.loc[polyp_order.index]

# %%
# find variable genes

import anndata

# %%
adata = anndata.AnnData(data.loc[list(no_polyp_order.index)+list(polyp_order.index)])

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
adata.raw=adata

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=500)

# %%
# add genes from prior work
additional_genes = ["POSTN","PTHLH","IGJ","IGHA1","ALOX15","EPAS1","ZG16B","LYZ","STATH","MSMB","IGHG4","SCGB1A1","CST1","IGFBP3","SCGB3A1","CST4","EGLN3","CDH26","PSCA","SERPINB2","IGHA2","LYPD2","CCL26","CST2"]
adata.var.highly_variable[additional_genes] = True

# %%
adata = adata[:, adata.var.highly_variable]

# %%
adata.write_h5ad("data/polyps/processed_adata.h5ad")

# %%
adata=sc.read_h5ad("data/polyps/processed_adata.h5ad")

# %%
adata
background = adata[no_polyp_order.index].X
foreground = adata[polyp_order.index].X

# %%
# lognormed data, top 500 variable genes, ordered by ints

# %%
#non polyp is foreground, polyp is background

# %%
import numpy as np
np.save( "data/polyps/no_polyp_lognorm_top500vargenes.npy",background)
np.save("data/polyps/polyp_lognorm_top500vargenes.npy",foreground)

# %%
import numpy as np
foreground = np.load("data/polyps/no_polyp_lognorm_top500vargenes.npy")
background = np.load("data/polyps/polyp_lognorm_top500vargenes.npy")

# %%
background.shape
# Out:
# (3898, 504)

# %%
st = time.time()
model = LinearCRBZ()
model.fit(foreground, background, no_polyp_order.to_numpy(),d=3,verbose=False,print_every=1000000)
preds = model.predict(foreground)
et=time.time()
print("time elapsed "+str(et-st))
# Out:
# time elapsed 661.9912612438202

# %%
from sklearn.metrics import r2_score
from scipy.stats import linregress

_, _, r2_contrastivereg, _, _ = linregress(no_polyp_order.to_numpy().squeeze(), preds)

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
font = {"size": 20}
matplotlib.rc("font", **font)
matplotlib.rcParams["text.usetex"] = True

# %%
plt.scatter(no_polyp_order.to_numpy(),preds,c="black")
plt.xlabel(r"Pseudotime-defined $r$")
plt.ylabel(r"Predicted $r$")
plt.title(r"$R^2 = " + str(round(r2_contrastivereg, 2)) + "$")
plt.tight_layout()
plt.savefig("r_squared_nopolyp.pdf")
plt.savefig("r_squared_nopolyp.png")

# %%
# try multiple numbers of dimensions
import os
n_dims = 10
for n_dims in [2,3,4,5,7,9,11,13,14]:
    model = LinearSSCR()
    model.fit(foreground, background, no_polyp_order.to_numpy(),d=n_dims,print_every=100)
    preds = model.predict(foreground)
    _, _, r2_contrastivereg, _, _ = linregress(no_polyp_order.to_numpy().squeeze(), preds)


    dirname = "dim"+str(n_dims)+"/"
    os.mkdir(dirname)
    plt.scatter(no_polyp_order.to_numpy(),preds,c="black")
    plt.xlabel(r"True $r$")
    plt.ylabel(r"Predicted $r$")
    plt.title(r"$R^2 = " + str(round(r2_contrastivereg, 2)) + "$")
    plt.tight_layout()
    plt.savefig(dirname+"rsquared.pdf")
    dims = ["Dim%d" % i for i in range(0,n_dims)]
    loading_w = pd.DataFrame(model.W, columns = adata.var_names, index = dims,dtype = "float")
    loading_w.to_csv(dirname+"W.csv")
    #latent_t = pd.DataFrame(model.t, columns = dims, index = asd_sample, dtype="float")
    #latent_t.to_csv(dirname+"t.csv")
    auxiliary_s = pd.DataFrame(model.S, columns = adata.var_names, index = dims, dtype="float")
    auxiliary_s.to_csv(dirname+"S.csv")
    betas = pd.DataFrame(data=model.beta)
    betas.to_csv(dirname+"beta.csv")
# Out:
# Step: 0               Log marginal lik.: -7159427584.0
# Step: 100             Log marginal lik.: -1839090688.0
# Step: 200             Log marginal lik.: -1050838720.0
# Step: 300             Log marginal lik.: -757059200.0
# Step: 400             Log marginal lik.: -598891392.0
# Step: 500             Log marginal lik.: -498463424.0
# Step: 600             Log marginal lik.: -428328288.0
# Step: 700             Log marginal lik.: -376231776.0
# Step: 800             Log marginal lik.: -335785184.0
# Step: 900             Log marginal lik.: -303365280.0
# Step: 1000            Log marginal lik.: -276682976.0
# Step: 1100            Log marginal lik.: -254318224.0
# Step: 1200            Log marginal lik.: -235232288.0
# Step: 1300            Log marginal lik.: -218741984.0
# Step: 1400            Log marginal lik.: -204309264.0
# Step: 1500            Log marginal lik.: -191556480.0
# Step: 1600            Log marginal lik.: -180192912.0
# Step: 1700            Log marginal lik.: -169997680.0
# Step: 1800            Log marginal lik.: -160757632.0
# Step: 1900            Log marginal lik.: -152357616.0
# Step: 2000            Log marginal lik.: -144666224.0
# Step: 2100            Log marginal lik.: -137589984.0
# Step: 2200            Log marginal lik.: -131042280.0
# Step: 2300            Log marginal lik.: -124960392.0
# Step: 2400            Log marginal lik.: -119284984.0
# Step: 2500            Log marginal lik.: -113970736.0
# Step: 2600            Log marginal lik.: -108970208.0
# Step: 2700            Log marginal lik.: -104248784.0
# Step: 2800            Log marginal lik.: -99772072.0
# Step: 2900            Log marginal lik.: -95511160.0
# Step: 3000            Log marginal lik.: -91438696.0
# Step: 3100            Log marginal lik.: -87528912.0
# Step: 3200            Log marginal lik.: -83757464.0
# Step: 3300            Log marginal lik.: -80102544.0
# Step: 3400            Log marginal lik.: -76539744.0
# Step: 3500            Log marginal lik.: -73048520.0
# Step: 3600            Log marginal lik.: -69604000.0
# Step: 3700            Log marginal lik.: -66184596.0
# Step: 3800            Log marginal lik.: -62767452.0
# Step: 3900            Log marginal lik.: -59330828.0
# Step: 4000            Log marginal lik.: -55854480.0
# Step: 4100            Log marginal lik.: -52322128.0
# Step: 4200            Log marginal lik.: -48725412.0
# Step: 4300            Log marginal lik.: -45065476.0
# Step: 4400            Log marginal lik.: -41359124.0
# Step: 4500            Log marginal lik.: -37640020.0
# Step: 4600            Log marginal lik.: -33959812.0
# Step: 4700            Log marginal lik.: -30381648.0
# Step: 4800            Log marginal lik.: -26973092.0
# Step: 4900            Log marginal lik.: -23793922.0
# Step: 5000            Log marginal lik.: -20887896.0
# Step: 5100            Log marginal lik.: -18277976.0
# Step: 5200            Log marginal lik.: -15966963.0
# Step: 5300            Log marginal lik.: -13942242.0
# Step: 5400            Log marginal lik.: -12180756.0
# Step: 5500            Log marginal lik.: -10654486.0
# Step: 5600            Log marginal lik.: -9334025.0
# Step: 5700            Log marginal lik.: -8191254.5
# Step: 5800            Log marginal lik.: -7200576.0
# Step: 5900            Log marginal lik.: -6339450.5
# Step: 6000            Log marginal lik.: -5588421.0
# Step: 6100            Log marginal lik.: -4931058.0
# Step: 6200            Log marginal lik.: -4353433.5
# Step: 6300            Log marginal lik.: -3843889.5
# Step: 6400            Log marginal lik.: -3392688.0
# Step: 6500            Log marginal lik.: -2991673.0
# Step: 6600            Log marginal lik.: -2634009.25
# Step: 6700            Log marginal lik.: -2313940.5
# Step: 6800            Log marginal lik.: -2026617.12
# Step: 6900            Log marginal lik.: -1767913.62
# Step: 7000            Log marginal lik.: -1534317.38
# Step: 7100            Log marginal lik.: -1322832.0
# Step: 7200            Log marginal lik.: -1130865.38
# Step: 7300            Log marginal lik.: -956199.38
# Step: 7400            Log marginal lik.: -796909.12
# Step: 7500            Log marginal lik.: -651315.25
# Step: 7600            Log marginal lik.: -517963.62
# Step: 7700            Log marginal lik.: -395587.62
# Step: 7800            Log marginal lik.: -283071.25
# Step: 7900            Log marginal lik.: -179439.75
# Step: 8000            Log marginal lik.: -83828.0
# Step: 8100            Log marginal lik.: 4523.75
# Step: 8200            Log marginal lik.: 86290.25
# Step: 8300            Log marginal lik.: 162069.5
# Step: 8400            Log marginal lik.: 232395.75
# Step: 8500            Log marginal lik.: 297742.38
# Step: 8600            Log marginal lik.: 358534.75
# Step: 8700            Log marginal lik.: 415157.25
# Step: 8800            Log marginal lik.: 467949.19
# Step: 8900            Log marginal lik.: 517222.81
# Step: 9000            Log marginal lik.: 563254.5
# Step: 9100            Log marginal lik.: 606297.31
# Step: 9200            Log marginal lik.: 646579.25
# Step: 9300            Log marginal lik.: 684308.75
# Step: 9400            Log marginal lik.: 719674.88
# Step: 9500            Log marginal lik.: 752850.56
# Step: 9600            Log marginal lik.: 783990.38
# Step: 9700            Log marginal lik.: 813238.31
# Step: 9800            Log marginal lik.: 840729.12
# Step: 9900            Log marginal lik.: 866580.12
# Step: 10000           Log marginal lik.: 890904.5
# Step: 10100           Log marginal lik.: 913803.12
# Step: 10200           Log marginal lik.: 935371.88
# Step: 10300           Log marginal lik.: 955697.38
# Step: 10400           Log marginal lik.: 974855.56
# Step: 10500           Log marginal lik.: 992926.88
# Step: 10600           Log marginal lik.: 1009975.38
# Step: 10700           Log marginal lik.: 1026066.5
# Step: 10800           Log marginal lik.: 1041259.38
# Step: 10900           Log marginal lik.: 1055609.25
# Step: 11000           Log marginal lik.: 1069166.25
# Step: 11100           Log marginal lik.: 1081978.75
# Step: 11200           Log marginal lik.: 1094090.75
# Step: 11300           Log marginal lik.: 1105542.25
# Step: 11400           Log marginal lik.: 1116375.25
# Step: 11500           Log marginal lik.: 1126620.88
# Step: 11600           Log marginal lik.: 1136318.25
# Step: 11700           Log marginal lik.: 1145493.75
# Step: 11800           Log marginal lik.: 1154180.75
# Step: 11900           Log marginal lik.: 1162405.62
# Step: 12000           Log marginal lik.: 1170192.12
# Step: 12100           Log marginal lik.: 1177567.38
# Step: 12200           Log marginal lik.: 1184553.5
# Step: 12300           Log marginal lik.: 1191172.25
# Step: 12400           Log marginal lik.: 1197442.5
# Step: 12500           Log marginal lik.: 1203384.12
# Step: 12600           Log marginal lik.: 1209014.75
# Step: 12700           Log marginal lik.: 1214351.5
# Step: 12800           Log marginal lik.: 1219408.75
# Step: 12900           Log marginal lik.: 1224203.5
# Step: 13000           Log marginal lik.: 1228748.38
# Step: 13100           Log marginal lik.: 1233056.75
# Step: 13200           Log marginal lik.: 1237142.12
# Step: 13300           Log marginal lik.: 1241015.12
# Step: 13400           Log marginal lik.: 1244687.75
# Step: 13500           Log marginal lik.: 1248170.0
# Step: 13600           Log marginal lik.: 1251471.12
# Step: 13700           Log marginal lik.: 1254601.38
# Step: 13800           Log marginal lik.: 1257569.5
# Step: 13900           Log marginal lik.: 1260384.25
# Step: 14000           Log marginal lik.: 1263053.0
# Step: 14100           Log marginal lik.: 1265584.38
# Step: 14200           Log marginal lik.: 1267983.75
# Step: 14300           Log marginal lik.: 1270258.25
# Step: 14400           Log marginal lik.: 1272415.12
# Step: 14500           Log marginal lik.: 1274460.0
# Step: 14600           Log marginal lik.: 1276398.88
# Step: 14700           Log marginal lik.: 1278236.5
# Step: 14800           Log marginal lik.: 1279978.75
# Step: 14900           Log marginal lik.: 1281629.5
# Step: 15000           Log marginal lik.: 1283194.0
# Step: 15100           Log marginal lik.: 1284677.25
# Step: 15200           Log marginal lik.: 1286081.75
# Step: 15300           Log marginal lik.: 1287412.5
# Step: 15400           Log marginal lik.: 1288673.25
# Step: 15500           Log marginal lik.: 1289868.25
# Step: 15600           Log marginal lik.: 1290998.75
# Step: 15700           Log marginal lik.: 1292070.0
# Step: 15800           Log marginal lik.: 1293084.0
# Step: 15900           Log marginal lik.: 1294043.38
# Step: 16000           Log marginal lik.: 1294951.38
# Step: 16100           Log marginal lik.: 1295811.25
# Step: 16200           Log marginal lik.: 1296624.0
# Step: 16300           Log marginal lik.: 1297392.88
# Step: 16400           Log marginal lik.: 1298119.5
# Step: 16500           Log marginal lik.: 1298806.25
# Step: 16600           Log marginal lik.: 1299455.25
# Step: 16700           Log marginal lik.: 1300069.0
# Step: 16800           Log marginal lik.: 1300648.0
# Step: 16900           Log marginal lik.: 1301194.5
# Step: 17000           Log marginal lik.: 1301710.25
# Step: 17100           Log marginal lik.: 1302197.38
# Step: 17200           Log marginal lik.: 1302656.0
# Step: 17300           Log marginal lik.: 1303088.75
# Step: 17400           Log marginal lik.: 1303495.75
# Step: 17500           Log marginal lik.: 1303879.62
# Step: 17600           Log marginal lik.: 1304241.38
# Step: 17700           Log marginal lik.: 1304580.5
# Step: 17800           Log marginal lik.: 1304900.75
# Step: 17900           Log marginal lik.: 1305200.25
# Step: 18000           Log marginal lik.: 1305482.0
# Step: 18100           Log marginal lik.: 1305746.25
# Step: 18200           Log marginal lik.: 1305994.88
# Step: 18300           Log marginal lik.: 1306226.12
# Step: 18400           Log marginal lik.: 1306444.25
# Step: 18500           Log marginal lik.: 1306646.75
# Step: 18600           Log marginal lik.: 1306837.25
# Step: 18700           Log marginal lik.: 1307014.5
# Step: 18800           Log marginal lik.: 1307180.5
# Step: 18900           Log marginal lik.: 1307334.75
# Step: 19000           Log marginal lik.: 1307478.25
# Step: 19100           Log marginal lik.: 1307611.75
# Step: 19200           Log marginal lik.: 1307735.75
# Step: 19300           Log marginal lik.: 1307851.0
# Step: 19400           Log marginal lik.: 1307956.75
# Step: 19500           Log marginal lik.: 1308055.12
# Step: 19600           Log marginal lik.: 1308146.12
# Step: 0               Log marginal lik.: -7880512512.0
# Step: 100             Log marginal lik.: -1746081536.0
# Step: 200             Log marginal lik.: -990211712.0
# Step: 300             Log marginal lik.: -714037376.0
# Step: 400             Log marginal lik.: -565688960.0
# Step: 500             Log marginal lik.: -471511488.0
# Step: 600             Log marginal lik.: -405696320.0
# Step: 700             Log marginal lik.: -356783584.0
# Step: 800             Log marginal lik.: -318840640.0
# Step: 900             Log marginal lik.: -288429824.0
# Step: 1000            Log marginal lik.: -263414288.0
# Step: 1100            Log marginal lik.: -242454048.0
# Step: 1200            Log marginal lik.: -224585312.0
# Step: 1300            Log marginal lik.: -209178560.0
# Step: 1400            Log marginal lik.: -195678320.0
# Step: 1500            Log marginal lik.: -183780576.0
# Step: 1600            Log marginal lik.: -173188416.0
# Step: 1700            Log marginal lik.: -163663712.0
# Step: 1800            Log marginal lik.: -155068128.0
# Step: 1900            Log marginal lik.: -147263472.0
# Step: 2000            Log marginal lik.: -140128384.0
# Step: 2100            Log marginal lik.: -133587248.0
# Step: 2200            Log marginal lik.: -127550920.0
# Step: 2300            Log marginal lik.: -121961208.0
# Step: 2400            Log marginal lik.: -116780016.0
# Step: 2500            Log marginal lik.: -111950656.0
# Step: 2600            Log marginal lik.: -107442592.0
# Step: 2700            Log marginal lik.: -103217936.0
# Step: 2800            Log marginal lik.: -99250328.0
# Step: 2900            Log marginal lik.: -95515616.0
# Step: 3000            Log marginal lik.: -92000784.0
# Step: 3100            Log marginal lik.: -88671192.0
# Step: 3200            Log marginal lik.: -85519864.0
# Step: 3300            Log marginal lik.: -82531192.0
# Step: 3400            Log marginal lik.: -79694704.0
# Step: 3500            Log marginal lik.: -76994296.0
# Step: 3600            Log marginal lik.: -74422624.0
# Step: 3700            Log marginal lik.: -71970336.0
# Step: 3800            Log marginal lik.: -69626784.0
# Step: 3900            Log marginal lik.: -67389456.0
# Step: 4000            Log marginal lik.: -65245204.0
# Step: 4100            Log marginal lik.: -63194004.0
# Step: 4200            Log marginal lik.: -61220864.0
# Step: 4300            Log marginal lik.: -59327748.0
# Step: 4400            Log marginal lik.: -57512128.0
# Step: 4500            Log marginal lik.: -55766292.0
# Step: 4600            Log marginal lik.: -54083236.0
# Step: 4700            Log marginal lik.: -52461116.0
# Step: 4800            Log marginal lik.: -50901384.0
# Step: 4900            Log marginal lik.: -49398632.0
# Step: 5000            Log marginal lik.: -47940848.0
# Step: 5100            Log marginal lik.: -46536520.0
# Step: 5200            Log marginal lik.: -45179828.0
# Step: 5300            Log marginal lik.: -43866180.0
# Step: 5400            Log marginal lik.: -42599980.0
# Step: 5500            Log marginal lik.: -41369864.0
# Step: 5600            Log marginal lik.: -40180608.0
# Step: 5700            Log marginal lik.: -39027628.0
# Step: 5800            Log marginal lik.: -37915180.0
# Step: 5900            Log marginal lik.: -36837172.0
# Step: 6000            Log marginal lik.: -35786036.0
# Step: 6100            Log marginal lik.: -34767948.0
# Step: 6200            Log marginal lik.: -33781284.0
# Step: 6300            Log marginal lik.: -32821528.0
# Step: 6400            Log marginal lik.: -31888550.0
# Step: 6500            Log marginal lik.: -30982562.0
# Step: 6600            Log marginal lik.: -30098028.0
# Step: 6700            Log marginal lik.: -29237490.0
# Step: 6800            Log marginal lik.: -28397772.0
# Step: 6900            Log marginal lik.: -27577490.0
# Step: 7000            Log marginal lik.: -26776972.0
# Step: 7100            Log marginal lik.: -25994944.0
# Step: 7200            Log marginal lik.: -25227466.0
# Step: 7300            Log marginal lik.: -24469294.0
# Step: 7400            Log marginal lik.: -23724754.0
# Step: 7500            Log marginal lik.: -22989982.0
# Step: 7600            Log marginal lik.: -22261502.0
# Step: 7700            Log marginal lik.: -21531746.0
# Step: 7800            Log marginal lik.: -20799918.0
# Step: 7900            Log marginal lik.: -20058288.0
# Step: 8000            Log marginal lik.: -19298660.0
# Step: 8100            Log marginal lik.: -18509272.0
# Step: 8200            Log marginal lik.: -17673256.0
# Step: 8300            Log marginal lik.: -16767458.0
# Step: 8400            Log marginal lik.: -15759706.0
# Step: 8500            Log marginal lik.: -14607829.0
# Step: 8600            Log marginal lik.: -13262110.0
# Step: 8700            Log marginal lik.: -11682349.0
# Step: 8800            Log marginal lik.: -9878423.0
# Step: 8900            Log marginal lik.: -7958502.0
# Step: 9000            Log marginal lik.: -6118510.0
# Step: 9100            Log marginal lik.: -4537670.0
# Step: 9200            Log marginal lik.: -3286727.0
# Step: 9300            Log marginal lik.: -2339185.0
# Step: 9400            Log marginal lik.: -1630328.0
# Step: 9500            Log marginal lik.: -1096588.0
# Step: 9600            Log marginal lik.: -688578.38
# Step: 9700            Log marginal lik.: -371214.25
# Step: 9800            Log marginal lik.: -120234.5
# Step: 9900            Log marginal lik.: 81298.69
# Step: 10000           Log marginal lik.: 245449.12
# Step: 10100           Log marginal lik.: 380930.12
# Step: 10200           Log marginal lik.: 494119.5
# Step: 10300           Log marginal lik.: 589735.06
# Step: 10400           Log marginal lik.: 671311.94
# Step: 10500           Log marginal lik.: 741526.94
# Step: 10600           Log marginal lik.: 802450.12
# Step: 10700           Log marginal lik.: 855685.5
# Step: 10800           Log marginal lik.: 902502.62
# Step: 10900           Log marginal lik.: 943914.12
# Step: 11000           Log marginal lik.: 980732.56
# Step: 11100           Log marginal lik.: 1013624.94
# Step: 11200           Log marginal lik.: 1043140.94
# Step: 11300           Log marginal lik.: 1069730.62
# Step: 11400           Log marginal lik.: 1093774.12
# Step: 11500           Log marginal lik.: 1115587.12
# Step: 11600           Log marginal lik.: 1135438.0
# Step: 11700           Log marginal lik.: 1153554.75
# Step: 11800           Log marginal lik.: 1170131.75
# Step: 11900           Log marginal lik.: 1185337.75
# Step: 12000           Log marginal lik.: 1199315.75
# Step: 12100           Log marginal lik.: 1212191.25
# Step: 12200           Log marginal lik.: 1224074.12
# Step: 12300           Log marginal lik.: 1235060.25
# Step: 12400           Log marginal lik.: 1245233.0
# Step: 12500           Log marginal lik.: 1254667.0
# Step: 12600           Log marginal lik.: 1263427.25
# Step: 12700           Log marginal lik.: 1271574.25
# Step: 12800           Log marginal lik.: 1279158.25
# Step: 12900           Log marginal lik.: 1286226.75
# Step: 13000           Log marginal lik.: 1292822.12
# Step: 13100           Log marginal lik.: 1298981.0
# Step: 13200           Log marginal lik.: 1304738.0
# Step: 13300           Log marginal lik.: 1310124.5
# Step: 13400           Log marginal lik.: 1315167.0
# Step: 13500           Log marginal lik.: 1319891.75
# Step: 13600           Log marginal lik.: 1324321.75
# Step: 13700           Log marginal lik.: 1328478.0
# Step: 13800           Log marginal lik.: 1332379.75
# Step: 13900           Log marginal lik.: 1336044.38
# Step: 14000           Log marginal lik.: 1339488.0
# Step: 14100           Log marginal lik.: 1342725.5
# Step: 14200           Log marginal lik.: 1345770.25
# Step: 14300           Log marginal lik.: 1348636.25
# Step: 14400           Log marginal lik.: 1351333.25
# Step: 14500           Log marginal lik.: 1353872.62
# Step: 14600           Log marginal lik.: 1356264.62
# Step: 14700           Log marginal lik.: 1358518.0
# Step: 14800           Log marginal lik.: 1360642.0
# Step: 14900           Log marginal lik.: 1362643.5
# Step: 15000           Log marginal lik.: 1364530.88
# Step: 15100           Log marginal lik.: 1366309.75
# Step: 15200           Log marginal lik.: 1367988.0
# Step: 15300           Log marginal lik.: 1369570.62
# Step: 15400           Log marginal lik.: 1371063.38
# Step: 15500           Log marginal lik.: 1372471.88
# Step: 15600           Log marginal lik.: 1373800.62

# %%
# is the min beta similar
for n_dims in [2,3,4,5,7,9,10,11,13,14]:
    dirname = "dim"+str(n_dims)+"/"
    print("dim"+str(n_dims))
    loading_w = pd.read_csv(dirname+"W.csv",index_col=0)
    betas = pd.read_csv(dirname+"beta.csv",index_col=0)
    max_dim = "Dim"+ str(betas["0"].argmax())
    print(loading_w.loc[max_dim].sort_values())
# Out:
# dim2
# BMX       -0.003511
# RGS13     -0.003184
# LRMP      -0.002317
# PLCB2     -0.002052
# CCDC129   -0.001731
#              ...
# STATH      1.370089
# MSMB       1.483295
# S100A4     1.486222
# BPIFA1     1.582396
# BPIFB1     1.765916
# Name: Dim0, Length: 504, dtype: float64
# dim3
# CLCA4            -0.010052
# AC104024.1       -0.000426
# AP000654.4       -0.000363
# RP11-1299A16.3   -0.000246
# CLEC17A          -0.000226
#                     ...
# MTRNR2L1          1.224571
# STATH             1.412773
# BPIFA1            1.606660
# MSMB              1.608337
# BPIFB1            1.844332
# Name: Dim1, Length: 504, dtype: float64
# dim4
# CEACAM5    -0.014345
# CEACAM6    -0.006412
# SAA2       -0.004293
# MUC5AC     -0.002181
# SPRR3      -0.001759
#               ...
# ALOX15      0.983226
# BPIFA1      1.378322
# MTRNR2L1    1.596963
# EPAS1       1.862047
# STATH       2.056753
# Name: Dim0, Length: 504, dtype: float64
# dim5
# KRT15     -0.320356
# MUC5AC    -0.258696
# TFF3      -0.252038
# SPINK5    -0.171956
# POSTN     -0.156444
#              ...
# RARRES1    0.579670
# ALOX15     0.601590
# S100A4     0.693731
# BPIFA1     0.885527
# SCGB1A1    1.068229
# Name: Dim0, Length: 504, dtype: float64
# dim7
# SCGB1A1   -0.122000
# CFD       -0.036279
# GDF15     -0.033128
# CST2      -0.015090
# CST4      -0.012095
#              ...
# LYZ        0.553692
# STATH      0.582337
# BPIFB1     0.745290
# MSMB       0.771901
# MT2A       0.856220
# Name: Dim3, Length: 504, dtype: float64
# dim9
# KRT15     -0.161106
# MUC5AC    -0.104903
# SPINK5    -0.078790
# POSTN     -0.057533
# FN1       -0.048021
#              ...
# BPIFB1     0.556371
# RARRES1    0.578730
# BPIFA1     0.603908
# STATH      0.800716
# EPAS1      0.818564
# Name: Dim5, Length: 504, dtype: float64
# dim10
# KRT15    -0.240399
# SPINK5   -0.127740
# POSTN    -0.086482
# CTGF     -0.081598
# PTHLH    -0.064573
#             ...
# EPAS1     0.589088
# C8orf4    0.638022
# MSMB      0.647103
# BPIFA1    0.650624
# STATH     0.838961
# Name: Dim8, Length: 504, dtype: float64
# dim11
# IGHA1      -0.134285
# LCN2       -0.105507
# POSTN      -0.087506
# CST1       -0.076726
# MTRNR2L6   -0.066860
#               ...
# GDF15       0.426620
# C8orf4      0.448590
# SCGB1A1     0.554608
# S100A4      0.812789
# EPAS1       0.976203
# Name: Dim7, Length: 504, dtype: float64
# dim13
# MSMB            -0.182783
# CTD-2319I12.1   -0.178958
# SCGB1A1         -0.178857
# C8orf4          -0.178202
# BPIFB1          -0.132180
#                    ...
# BPIFA1           0.279739
# RARRES1          0.319287
# EPAS1            0.381700
# S100A4           0.426326
# MTRNR2L1         0.575610
# Name: Dim0, Length: 504, dtype: float64
# dim14
# TMEM213    -0.297866
# SCGB1A1    -0.288876
# CFD        -0.200064
# CXCL1      -0.199225
# MUC5AC     -0.196741
#               ...
# LCN2        0.263985
# MTRNR2L1    0.300284
# S100A4      0.303633
# ZG16B       0.436183
# S100A9      0.448643
# Name: Dim9, Length: 504, dtype: float64

# %%
dims = ["Dim%d" % i for i in range(0,3)]
loading_w = pd.DataFrame(model.W, columns = adata.var_names, index = dims,dtype = "float")
betas = pd.DataFrame(data=model.beta)

# %%
loading_w.to_csv("loadings_unscaled_d3.csv")

# %%
corr_genes=pd.read_csv("correlated_genes.txt")["genes"].values

# %%
plt.scatter(list(range(0,504)),(loading_w.loc["Dim1"].sort_values(ascending =False)),c=["k" if i in corr_genes else "c" for i in loading_w.loc["Dim1"].sort_values(ascending =False).index]
)
plt.ylabel("Loading")
plt.xlabel("Gene Index")
plt.savefig("ranked_loading_plot.pdf",bbox_inches="tight")

# %%
dim="Dim1"
plt.figure(figsize=(20,15))
for i in range(0,15):
    axs = plt.subplot(5,6,2*i+1)
    g=loading_w.loc[dim].sort_values(ascending=False).index[i]
    plotno = 2*i
    axs.scatter(no_polyp_order,foreground[:,list(adata.var_names).index(g)])
    axs.set_ylabel(g)
    axs = plt.subplot(5,6,2*i+2)
    axs.scatter(polyp_order,background[:,list(adata.var_names).index(g)],c="y")
    
plt.tight_layout()

# %%
preds_background = model.predict(background)
_, _, r2_contrastivereg_bg, _, _ = linregress(polyp_order.to_numpy().squeeze(), preds_background)

# %%
plt.scatter(polyp_order.to_numpy(),preds_background,c="black")
plt.xlabel(r"True $r$ background")
plt.ylabel(r"Predicted $r$ packground")
plt.title(r"$R^2 = " + str(round(r2_contrastivereg_bg, 2)) + "$")
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(foreground, columns=adata.var_names)
df["pseudotime order"] = no_polyp_order[1].values
df["state"] = "foreground"
df_2 = pd.DataFrame(background, columns=adata.var_names)
df_2["pseudotime order"] = polyp_order[1].values
df_2["state"] = "background"

exp = pd.concat([df,df_2])

# %%
font = {"size": 10}
matplotlib.rc("font", **font)
matplotlib.rcParams["text.usetex"] = True
import seaborn as sns
plt.figure(figsize=(10,7.5))
for i,g in enumerate(["SCGB3A1","BPIFA1","MUC5AC","MUC16","BPIFB1","POSTN","FN1","DLK2","DLL1","JAG2","KRT15","SPINK5"]):
    axs = plt.subplot(5,6,2*i+1)
    plotno = 2*i
    axs.scatter(no_polyp_order,foreground[:,list(adata.var_names).index(g)],s=3)
    axs.set_ylabel(g)
    axs.spines[['right', 'top']].set_visible(False)
    axs = plt.subplot(5,6,2*i+2)
    axs.scatter(polyp_order,background[:,list(adata.var_names).index(g)],c="orange",s=3)
    axs.spines[['right', 'top']].set_visible(False)
#ax = sns.lmplot(x="pseudotime order",y="SCGB3A1",col="state",hue="state",data=exp)
#plt.savefig("SCGB3A1_expression.pdf",bbox_inches="tight")
plt.tight_layout(w_pad=.7)
plt.savefig("supplemental_polyp_genes_expression.pdf",bbox_inches="tight")

# %%
# compare multiple random seeds

st = time.time()
model_10 = LinearCRBZ()
model_10.fit(foreground, background, no_polyp_order.to_numpy(),d=3,verbose=False,print_every=1000000,seed=10)
preds_10 = model_10.predict(foreground)
et=time.time()
print("time elapsed "+str(et-st))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 2024-07-02 15:26:25.965411: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:65] Constant folding an instruction is taking > 1s:
#
#   dot.14 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# 2024-07-02 15:26:27.295751: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:133] The operation took 2.330398717s
# Constant folding an instruction is taking > 1s:
#
#   dot.14 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# 2024-07-02 15:26:29.445270: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:65] Constant folding an instruction is taking > 2s:
#
#   dot.21 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# 2024-07-02 15:26:29.967256: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:133] The operation took 2.522066116s
# Constant folding an instruction is taking > 2s:
#
#   dot.21 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# time elapsed 651.1040480136871

# %%
st = time.time()
model_100 = LinearCRBZ()
model_100.fit(foreground, background, no_polyp_order.to_numpy(),d=3,verbose=False,print_every=1000000,seed=100)
preds_100 = model_100.predict(foreground)
et=time.time()
print("time elapsed "+str(et-st))

# %%
st = time.time()
model_150 = LinearCRBZ()
model_150.fit(foreground, background, no_polyp_order.to_numpy(),d=3,verbose=False,print_every=1000000,seed=150)
preds_150 = model_150.predict(foreground)
et=time.time()
print("time elapsed "+str(et-st))
# Out:
# time elapsed 636.8469140529633

# %%
betas_150 = pd.DataFrame(data=model_150.beta)

# %%
betas_100 = pd.DataFrame(data=model_100.beta)

# %%
betas_10
# Out:
#            0
# 0  -7.357260
# 1   7.888663
# 2  18.833319

# %%
betas_100
# Out:
#            0
# 0 -15.104368
# 1 -13.603994
# 2 -11.902008

# %%
betas_150
# Out:
#            0
# 0  14.310707
# 1  16.167130
# 2  19.386011

# %%
dims = ["Dim%d" % i for i in range(0,3)]
loading_w_10 = pd.DataFrame(model_10.W, columns = adata.var_names, index = dims,dtype = "float")
loading_w_100 = pd.DataFrame(model_100.W, columns = adata.var_names, index = dims,dtype = "float")
loading_w_150 = pd.DataFrame(model_150.W, columns = adata.var_names, index = dims,dtype = "float")

# %%
genes_ranked_10 = pd.DataFrame(loading_w_10.loc["Dim2"].sort_values())
genes_ranked_10["rank"] = list(range(0,504))

# %%
genes_ranked_100 = pd.DataFrame(loading_w_100.loc["Dim0"].sort_values(ascending =False))# not ascending because this beta is negative 
genes_ranked_100["rank"] = list(range(0,504))

# %%
genes_ranked_150 = pd.DataFrame(loading_w_150.loc["Dim2"].sort_values())# not ascending because this beta is negative 
genes_ranked_150["rank"] = list(range(0,504))

# %%
genes_ranked_100.loc[genes_ranked_150.index]
# Out:
#              Dim0  rank
# KRT15   -0.963582   496
# POSTN   -0.562083   489
# SPINK5  -0.561557   488
# FN1     -0.230696   453
# KAL1    -0.210504   447
# ...           ...   ...
# RARRES1 -0.298456   470
# BPIFA1  -1.673165   500
# PSCA    -0.249426   459
# SCGB1A1 -0.619601   490
# S100A4  -0.797584   494
#
# [504 rows x 2 columns]

# %%
genes_ranked_10
# Out:
#              Dim2  rank
# KRT15   -0.083761     0
# SPINK5  -0.055642     1
# FN1     -0.041319     2
# DLK2    -0.031330     3
# NPPC    -0.022035     4
# ...           ...   ...
# S100A4   1.311408   499
# SCGB1A1  1.352976   500
# MSMB     1.380603   501
# BPIFA1   1.488957   502
# BPIFB1   1.537372   503
#
# [504 rows x 2 columns]

# %%
plt.scatter(genes_ranked_150["rank"],genes_ranked_10.loc[genes_ranked_150.index,"rank"],c="k",s=5)
plt.plot([0,505],[0,505],linestyle="dashed", color="red")
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.ylabel("Gene Ranking (seed 10)")
plt.xlabel("Gene Ranking (seed 150)")
plt.savefig("random_seed_comparison.pdf")

# %%
# compare to linear regression
import time
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score
from scipy.stats import linregress
R=no_polyp_order.to_numpy()
st = time.time()
linreg = LinearRegression()
pca = PCA(n_components=3)
X_reduced =pca.fit_transform(foreground)
linreg.fit(X_reduced, R)
et = time.time()
preds_linreg = linreg.predict(X_reduced)
_, _, r2_linreg, _, _ = linregress(R.squeeze(), preds_linreg.squeeze())
print("time elapsed "+str(et-st))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 7
#       5 from sklearn.metrics import r2_score
#       6 from scipy.stats import linregress
# ----> 7 R=no_polyp_order.to_numpy()
#       8 st = time.time()
#       9 linreg = LinearRegression()
#
# NameError: name 'no_polyp_order' is not defined

# %%
r2_linreg
# Out:
# 0.7856928770946668

# %%
pca.
# Out:
# (3686, 3)

# %%
loading_pca = pd.DataFrame(pca.components_, columns = adata.var_names).T

# %%
loading_pca.sort_values(0)
# Out:
#                 0         1         2
# KRT15   -0.141299  0.103882  0.225469
# POSTN   -0.106141  0.161948  0.189772
# SPINK5  -0.066941  0.018682  0.120475
# SULT1E1 -0.045777 -0.022856  0.016176
# FN1     -0.035778  0.025884  0.040855
# ...           ...       ...       ...
# LYPD2    0.259985 -0.002653 -0.035923
# S100P    0.260461 -0.063313  0.082678
# SCGB1A1  0.280142  0.077890 -0.329269
# MSMB     0.317462  0.036384  0.250038
# BPIFB1   0.356135  0.090172  0.255282
#
# [504 rows x 3 columns]

# %%
loading_w=pd.read_csv("loadings_unscaled_d3.csv",index_col=0)

# %%
loading_w = loading_w.T

# %%
plt.scatter(loading_w["Dim1"].abs().rank(),loading_pca[0].abs().rank())
plt.xlabel("CR rank")
plt.ylabel("PCA rank")
# Out:
# Text(0, 0.5, 'PCA rank')
